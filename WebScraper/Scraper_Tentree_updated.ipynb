# %%
from bs4 import BeautifulSoup
import urllib
import json
import os
import re
import requests
import pandas as pd
import re
import seaborn as sn
import matplotlib
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Mounted at drive

# %%
main_url = 'https://www.tentree.com/collections/mens-t-shirts-tanks'

# %% [markdown]
# ## Mens

# %%
def grab_tt():
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:50.0) Gecko/20100101 Firefox/50.0'}

    response = requests.get('https://www.tentree.com/collections/mens-t-shirts-tanks',
                            headers=headers).text

    soup = BeautifulSoup(response, 'html.parser')

    return soup

# %%
def parse_tt_test(soup):
    elements = []

    beginning = "{\"products\": "
    end = "}"

    script = soup.findAll('script')[51].text.strip()[130: -842]

    # Mens range: [130:-1060]

    script2 = beginning + script + end

    # data = json.loads(script2)

    return script2

# %%
def parse_tt(soup):
    elements = []

    beginning = "{\"products\": "
    end = "}"

    script = soup.findAll('script')[51].text.strip()[130: -842]

    # Mens range: [130:-1060]

    script2 = beginning + script + end

    data = json.loads(script2)

    return data

# %%
def item_list(items_dict):
    i = 0
    items_list = []
    urls = []

    for shirt in items_dict['products']:
        j = 0
        for variant in items_dict['products'][i]['variants']:
            inner_list = []

            shirt_name = items_dict['products'][i]['title']
            inner_list.append(shirt_name)

            image_url = items_dict['products'][i]['image']
            image_url = main_url + image_url
            inner_list.append(image_url)

            variant_color = items_dict['products'][i]['variants'][j]['options'][0]
            inner_list.append(variant_color)

            variant_size = items_dict['products'][i]['variants'][j]['options'][1]
            inner_list.append(variant_size)

            variant_url = str(items_dict['products'][0]['variants'][0]['variant_color_url'])
            variant_url_f = main_url + variant_url
            inner_list.append(variant_url_f)
            urls.append(variant_url)

            variant_price = (items_dict['products'][0]['variants'][0]['price'] / 100)
            inner_list.append(variant_price)

            items_list.append(inner_list)

            j += 1

        i += 1

    # columns_ = ['Name', 'image_url', 'color', 'size', 'item_url', 'price']

    return items_list, urls

# %%
def grab_ind_tt(url):
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:50.0) Gecko/20100101 Firefox/50.0'}

    response = requests.get(url, headers=headers).text

    soup = BeautifulSoup(response, 'html.parser')

    return soup

# %%
def new_urls_(urls_):
    new_urls = []
    for url in urls_:
        new_url = url.replace(" ", "%20")
        new_urls.append(new_url)

    return new_urls

# %%
  main_url = 'https://www.tentree.com/collections/mens-t-shirts-tanks'

  # soup = grab_tt()

  # print(soup)

  # items_dict = parse_tt_test(soup)
  items_dict = parse_tt(soup)

  # print(items_dict)

  items_, urls_ = item_list(items_dict) 

  new_urls = new_urls_(urls_)

  # Elements: fit/details, material, wash instructions, manufacturing info

  elements_all = []
  i = 0
  for site in new_urls:
      test_url = main_url + site

      soup2 = grab_ind_tt(test_url)

      soup3 = soup2.find('div', class_='product-description')
      soup3 = soup3.findAll('li', class_='')

      elements = []
      for i_ in soup3:
          for j_ in i_.contents:
              new_ele = str(j_).replace('??', '')
              elements.append(new_ele)

      elements_all.append(elements)

      i += 1


  i = 0
  for list_ in items_:
      j = 0
      for ele in elements_all[i]:
          list_.append(ele)
          j += 1
      i += 1


  headers = ['name', 'image_url', 'color', 'size', 'url', 'price', 'fit_features', 'materials', 'wash_dir', 'ethical_url']

  df_mens_tt = pd.DataFrame(items_, columns=headers)

  print(items_)
  print(len(items_))
# Out:
# [['Lorax Unless T-Shirt', 'https://www.tentree.com/collections/mens-t-shirts-tanks1/2341/3995/products/TCM4833-23151.jpg?v=1634833590', 'TWILIGHT BLUE', 'S', 'https://www.tentree.com/collections/mens-t-shirts-tanks/products/mens-lorax-unless-t-shirt?TWILIGHT BLUE', 40.0, 'Regular fit crew neck t-shirt, medium stretch', '45% REPREVE® Recycled Polyester, 30% TENCEL™ Lyocell, 25% Organic Cotton', 'Wash cold, tumble dry low', '<a href="/pages/ethical-manufacturing" target="_blank">Designed in Canada, ethically made in China</a>'], ['Lorax Unless T-Shirt', 'https://www.tentree.com/collections/mens-t-shirts-tanks1/2341/3995/products/TCM4833-23151.jpg?v=1634833590', 'TWILIGHT BLUE', 'M', 'https://www.tentree.com/collections/mens-t-shirts-tanks/products/mens-lorax-unless-t-shirt?TWILIGHT BLUE', 40.0, 'Regular fit crew neck t-shirt, medium stretch', '45% REPREVE® Recycled Polyester, 30% TENCEL™ Lyocell, 25% Organic Cotton', 'Wash cold, tumble dry low', '<a href="/pages/ethical-manufacturing" target="_blank">Designed in Canada, ethically made in China</a>'], ['Lorax Unless T-Shirt', 'https://www.tentree.com/collections/mens-t-shirts-tanks1/2341/3995/products/TCM4833-23151.jpg?v=1634833590', 'TWILIGHT BLUE', 'L', 'https://www.tentree.com/collections/mens-t-shirts-tanks/products/mens-lorax-unless-t-shirt?TWILIGHT BLUE', 40.0, 'Regular fit crew neck t-shirt, medium stretch', '45% REPREVE® Recycled Polyester, 30% TENCEL™ Lyocell, 25% Organic Cotton', 'Wash cold, tumble dry low', '<a href="/pages/ethical-manufacturing" target="_blank">Designed in Canada, ethically made in China</a>'], ['Lorax Unless T-Shirt', 'https://www.tentree.com/collections/mens-t-shirts-tanks1/2341/3995/products/TCM4833-23151.jpg?v=1634833590', 'TWILIGHT BLUE', 'XL', 'https://www.tentree.com/collections/mens-t-shirts-tanks/products/mens-lorax-unless-t-shirt?TWILIGHT BLUE', 40.0, 'Regular fit crew neck t-shirt, medium stretch', '45% REPREVE® Recycled Polyester, 30% TENCEL™ Lyocell, 25% Organic Cotton', 'Wash cold, tumble dry low', '<a href="/pages/ethical-manufacturing" target="_blank">Designed in Canada, ethically made in China</a>'], ['Lorax Unless T-Shirt', 'https://www.tentree.com/collections/mens-t-shirts-tanks1/2341/3995/products/TCM4833-23151.jpg?v=1634833590', 'METEORITE BLACK', 'S', 'https://www.tentree.com/collections/mens-t-shirts-tanks/products/mens-lorax-unless-t-shirt?TWILIGHT BLUE', 40.0, 'Regular fit crew neck t-shirt, medium stretch', '45% REPREVE® Recycled Polyester, 30% TENCEL™ Lyocell, 25% Organic Cotton', 'Wash cold, tumble dry low', '<a href="/pages/ethical-manufacturing" target="_blank">Designed in Canada, ethically made in China</a>'], ['Lorax Unless T-Shirt', 'https://www.tentree.com/collections/mens-t-shirts-tanks1/2341/3995/products/TCM4833-23151.jpg?v=1634833590', 'METEORITE BLACK', 'M', 'https://www.tentree.com/collections/mens-t-shirts-tanks/products/mens-lorax-unless-t-shirt?TWILIGHT BLUE', 40.0, 'Regular fit crew neck t-shirt, medium stretch', '45% REPREVE® Recycled Polyester, 30% TENCEL™ Lyocell, 25% Organic Cotton', 'Wash cold, tumble dry low', '<a href="/pages/ethical-manufacturing" target="_blank">Designed in Canada, ethically made in China</a>'], ['Lorax Unless T-Shirt', 'https://www.tentree.com/collections/mens-t-shirts-tanks1/2341/3995/products/TCM4833-23151.jpg?v=1634833590', 'METEORITE BLACK', 'L', 'https://www.tentree.com/collections/mens-t-shirts-tanks/products/mens-lorax-unless-t-shirt?TWILIGHT BLUE', 40.0, 'Regular fit crew neck t-shirt, medium stretch', '45% REPREVE® Recycled Polyester, 30% TENCEL™ Lyocell, 25% Organic Cotton', 'Wash cold, tumble dry low', '<a href="/pages/ethical-manufacturing" target="_blank">Designed in Canada, ethically made in China</a>'], ['Lorax Unless T-Shirt', 'https://www.tentree.com/collections/mens-t-shirts-tanks1/2341/3995/products/TCM4833-23151.jpg?v=1634833590', 'METEORITE BLACK', 'XL', 'https://www.tentree.com/collections/mens-t-shirts-tanks/products/mens-lorax-unless-t-shirt?TWILIGHT BLUE',  ...
# 210

# %%
df_mens_tt
# Out:
#                                              name  ...                                        ethical_url
# 0                            Lorax Unless T-Shirt  ...  <a href="/pages/ethical-manufacturing" target=...
# 1                            Lorax Unless T-Shirt  ...  <a href="/pages/ethical-manufacturing" target=...
# 2                            Lorax Unless T-Shirt  ...  <a href="/pages/ethical-manufacturing" target=...
# 3                            Lorax Unless T-Shirt  ...  <a href="/pages/ethical-manufacturing" target=...
# 4                            Lorax Unless T-Shirt  ...  <a href="/pages/ethical-manufacturing" target=...
# ..                                            ...  ...                                                ...
# 205    National Geographic Redwood Unisex T-Shirt  ...  <a href="/pages/ethical-manufacturing" target=...
# 206  National Geographic Banner Unisex Longsleeve  ...  <a href="/pages/ethical-manufacturing" target=...
# 207  National Geographic Banner Unisex Longsleeve  ...  <a href="/pages/ethical-manufacturing" target=...
# 208  National Geographic Banner Unisex Longsleeve  ...  <a href="/pages/ethical-manufacturing" target=...
# 209  National Geographic Banner Unisex Longsleeve  ...  <a href="/pages/ethical-manufacturing" target=...
#
# [210 rows x 10 columns]

# %%
df_mens_tt[['material1', 'material2', 'material3']] = df_mens_tt['materials'].str.split(",", expand=True)

# %%
df_mens_tt
# Out:
#                                              name  ...            material3
# 0                            Lorax Unless T-Shirt  ...   25% Organic Cotton
# 1                            Lorax Unless T-Shirt  ...   25% Organic Cotton
# 2                            Lorax Unless T-Shirt  ...   25% Organic Cotton
# 3                            Lorax Unless T-Shirt  ...   25% Organic Cotton
# 4                            Lorax Unless T-Shirt  ...   25% Organic Cotton
# ..                                            ...  ...                  ...
# 205    National Geographic Redwood Unisex T-Shirt  ...   25% Organic Cotton
# 206  National Geographic Banner Unisex Longsleeve  ...   25% Organic Cotton
# 207  National Geographic Banner Unisex Longsleeve  ...   25% Organic Cotton
# 208  National Geographic Banner Unisex Longsleeve  ...   25% Organic Cotton
# 209  National Geographic Banner Unisex Longsleeve  ...   25% Organic Cotton
#
# [210 rows x 13 columns]

# %% [markdown]
# Add gender

# %%
df_mens_tt['gender'] = "mens"

# %%
df_mens_tt
# Out:
#                                              name  ... gender
# 0                            Lorax Unless T-Shirt  ...   mens
# 1                            Lorax Unless T-Shirt  ...   mens
# 2                            Lorax Unless T-Shirt  ...   mens
# 3                            Lorax Unless T-Shirt  ...   mens
# 4                            Lorax Unless T-Shirt  ...   mens
# ..                                            ...  ...    ...
# 205    National Geographic Redwood Unisex T-Shirt  ...   mens
# 206  National Geographic Banner Unisex Longsleeve  ...   mens
# 207  National Geographic Banner Unisex Longsleeve  ...   mens
# 208  National Geographic Banner Unisex Longsleeve  ...   mens
# 209  National Geographic Banner Unisex Longsleeve  ...   mens
#
# [210 rows x 14 columns]

# %% [markdown]
# Reordering columns

# %%
df_mens_tt = df_mens_tt[['name', 'image_url', 'color', 'size', 'url', 'price', 'fit_features', 'materials', 'wash_dir', 'ethical_url', 'gender', 'material1', 'material2', 'material3']]

# %%
df_mens_tt
# Out:
#                                              name  ...            material3
# 0                            Lorax Unless T-Shirt  ...   25% Organic Cotton
# 1                            Lorax Unless T-Shirt  ...   25% Organic Cotton
# 2                            Lorax Unless T-Shirt  ...   25% Organic Cotton
# 3                            Lorax Unless T-Shirt  ...   25% Organic Cotton
# 4                            Lorax Unless T-Shirt  ...   25% Organic Cotton
# ..                                            ...  ...                  ...
# 205    National Geographic Redwood Unisex T-Shirt  ...   25% Organic Cotton
# 206  National Geographic Banner Unisex Longsleeve  ...   25% Organic Cotton
# 207  National Geographic Banner Unisex Longsleeve  ...   25% Organic Cotton
# 208  National Geographic Banner Unisex Longsleeve  ...   25% Organic Cotton
# 209  National Geographic Banner Unisex Longsleeve  ...   25% Organic Cotton
#
# [210 rows x 14 columns]

# %% [markdown]
# ## EDA

# %%
plot_order1 = df_mens_tt.groupby('price')['price'].sum().sort_values(ascending=True).index.values

# %%
sn.catplot('price', data=df_mens_tt, kind='count', height=10, aspect=1.5, order=plot_order1)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
g = sn.catplot('color', data=df_mens_tt, kind='count', height=10, aspect=2.5)
g.set_xticklabels(rotation=50)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
g = sns.barplot(x=["Asia", "Africa", "Antartica", "Europe"],
                y=[90, 30, 60, 10])
g.set_xticklabels(
    labels=["Asia", "Africa", "Antartica", "Europe"], rotation=30)
# Show the plot
plt.show()

# %%
sn.catplot('materials', data=df_mens_tt, kind='count', height=10, aspect=1.5)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # Phase II:

# %% [markdown]
# ## Womens

# %%
main_url_w = 'https://www.tentree.com/collections/womens-t-shirts-tanks'

# %%
def grab_tt_w():
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:50.0) Gecko/20100101 Firefox/50.0'}

    response = requests.get('https://www.tentree.com/collections/womens-t-shirts-tanks',
                            headers=headers).text

    soup = BeautifulSoup(response, 'html.parser')

    return soup

# %%
def parse_tt_w(soup):
    elements = []

    beginning = "{\"products\": "
    end = "}"

    script = soup.findAll('script')[51].text.strip()[130: -1033]

    # Mens range: [130:-1060]

    script2 = beginning + script + end

    data = json.loads(script2)

    return data

# %%
def parse_tt_w_test(soup):
    elements = []

    beginning = "{\"products\": "
    end = "}"

    script = soup.findAll('script')[51].text.strip()[130: -1033]

    # Mens range: [130:-1060]

    script2 = beginning + script + end

    # data = json.loads(script2)

    return script2

# %%
def item_list_(items_dict):
    i = 0
    items_list = []
    urls = []

    for shirt in items_dict['products']:
        j = 0
        for variant in items_dict['products'][i]['variants']:
            inner_list = []

            shirt_name = items_dict['products'][i]['title']
            inner_list.append(shirt_name)

            image_url = items_dict['products'][i]['image']
            image_url_f = main_url_w + image_url
            inner_list.append(image_url_f)

            variant_color = items_dict['products'][i]['variants'][j]['options'][0]
            inner_list.append(variant_color)

            variant_size = items_dict['products'][i]['variants'][j]['options'][1]
            inner_list.append(variant_size)

            variant_url = str(items_dict['products'][0]['variants'][0]['variant_color_url'])
            variant_url_f = main_url_w + variant_url
            inner_list.append(variant_url_f)
            urls.append(variant_url)

            variant_price = (items_dict['products'][0]['variants'][0]['price'] / 100)
            inner_list.append(variant_price)

            items_list.append(inner_list)

            j += 1

        i += 1

    # columns_ = ['Name', 'image_url', 'color', 'size', 'item_url', 'price']

    return items_list, urls

# %%
def grab_ind_tt(url):
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:50.0) Gecko/20100101 Firefox/50.0'}

    response = requests.get(url, headers=headers).text

    soup = BeautifulSoup(response, 'html.parser')

    return soup

# %%
def new_urls(urls_):
    new_urls = []
    for url in urls_:
        new_url = url.replace(" ", "%20")
        new_urls.append(new_url)

    return new_urls

# %% [markdown]
# ## Run the scrape

# %%
  main_url = 'https://www.tentree.com/collections/womens-t-shirts-tanks'

  soup_w = grab_tt_w()

  # print(soup_w)

  items_dict = parse_tt_w(soup)
  # script = parse_tt_w_test(soup_w)

  # print(items_dict)
  # print(script)

  items_w, urls_ = item_list(items_dict)

  # print(urls_)

  ## Remove the new_urls() as the womens urls are structured differently
  new_urls = urls_

  # Elements: fit/details, material, wash instructions, manufacturing info
  elements_all = []
  i = 0
  for site in new_urls:
      test_url = main_url + site

      soup2 = grab_ind_tt(test_url)

      soup3 = soup2.find('div', class_='product-description')
      soup3 = soup3.findAll('li', class_='')

      elements = []
      for i_ in soup3:
          for j_ in i_.contents:
              new_ele = str(j_).replace('??', '')
              elements.append(new_ele)

      elements_all.append(elements)

      i += 1


  i = 0
  for list_ in items_w:
      j = 0
      for ele in elements_all[i]:
          list_.append(ele)
          j += 1
      i += 1

  headers = ['name', 'image_url', 'color', 'size', 'url', 'price', 'fit_features', 'materials', 'wash_dir', 'ethical_url']

  df_womens_tt = pd.DataFrame(items_w, columns=headers)

  # df.to_csv('tentree_mens.csv', index=False, header=headers)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-87-1c989c7aefbb> in <module>()
#      24     test_url = main_url + site
#      25
# ---> 26     soup2 = grab_ind_tt(test_url)
#      27
#      28     soup3 = soup2.find('div', class_='product-description')
#
# <ipython-input-55-570cb9f1b5c3> in grab_ind_tt(url)
#       2     headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:50.0) Gecko/20100101 Firefox/50.0'}
#       3
# ----> 4     response = requests.get(url, headers=headers).text
#       5
#       6     soup = BeautifulSoup(response, 'html.parser')
#
# /usr/local/lib/python3.7/dist-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# /usr/local/lib/python3.7/dist-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /usr/local/lib/python3.7/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# /usr/local/lib/python3.7/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     681
#     682         if not stream:
# --> 683             r.content
#     684
#     685         return r
#
# /usr/local/lib/python3.7/dist-packages/requests/models.py in content(self)
#     827                 self._content = None
#     828             else:
# --> 829                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     830
#     831         self._content_consumed = True
#
# /usr/local/lib/python3.7/dist-packages/requests/models.py in generate()
#     749             if hasattr(self.raw, 'stream'):
#     750                 try:
# --> 751                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     752                         yield chunk
#     753                 except ProtocolError as e:
#
# /usr/local/lib/python3.7/dist-packages/urllib3/response.py in stream(self, amt, decode_content)
#     490         """
#     491         if self.chunked and self.supports_chunked_reads():
# --> 492             for line in self.read_chunked(amt, decode_content=decode_content):
#     493                 yield line
#     494         else:
#
# /usr/local/lib/python3.7/dist-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     666
#     667             while True:
# --> 668                 self._update_chunk_length()
#     669                 if self.chunk_left == 0:
#     670                     break
#
# /usr/local/lib/python3.7/dist-packages/urllib3/response.py in _update_chunk_length(self)
#     598         if self.chunk_left is not None:
#     599             return
# --> 600         line = self._fp.fp.readline()
#     601         line = line.split(b';', 1)[0]
#     602         try:
#
# /usr/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /usr/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
  print(items_w)
  print(len(items_w))
# Out:
# [['The Lorax T-Shirt', 'https://www.tentree.com/collections/womens-t-shirts-tanks1/2341/3995/products/TCW4834-0164.jpg?v=1634833601', 'METEORITE BLACK', 'XS', 'https://www.tentree.com/collections/womens-t-shirts-tanks/products/womens-lorax-t-shirt?METEORITE BLACK', 40.0], ['The Lorax T-Shirt', 'https://www.tentree.com/collections/womens-t-shirts-tanks1/2341/3995/products/TCW4834-0164.jpg?v=1634833601', 'METEORITE BLACK', 'S', 'https://www.tentree.com/collections/womens-t-shirts-tanks/products/womens-lorax-t-shirt?METEORITE BLACK', 40.0], ['The Lorax T-Shirt', 'https://www.tentree.com/collections/womens-t-shirts-tanks1/2341/3995/products/TCW4834-0164.jpg?v=1634833601', 'METEORITE BLACK', 'M', 'https://www.tentree.com/collections/womens-t-shirts-tanks/products/womens-lorax-t-shirt?METEORITE BLACK', 40.0], ['The Lorax T-Shirt', 'https://www.tentree.com/collections/womens-t-shirts-tanks1/2341/3995/products/TCW4834-0164.jpg?v=1634833601', 'METEORITE BLACK', 'L', 'https://www.tentree.com/collections/womens-t-shirts-tanks/products/womens-lorax-t-shirt?METEORITE BLACK', 40.0], ['The Lorax T-Shirt', 'https://www.tentree.com/collections/womens-t-shirts-tanks1/2341/3995/products/TCW4834-0164.jpg?v=1634833601', 'METEORITE BLACK', 'XL', 'https://www.tentree.com/collections/womens-t-shirts-tanks/products/womens-lorax-t-shirt?METEORITE BLACK', 40.0], ['The Lorax T-Shirt', 'https://www.tentree.com/collections/womens-t-shirts-tanks1/2341/3995/products/TCW4834-0164.jpg?v=1634833601', 'DEEP JUNGLE', 'XS', 'https://www.tentree.com/collections/womens-t-shirts-tanks/products/womens-lorax-t-shirt?METEORITE BLACK', 40.0], ['The Lorax T-Shirt', 'https://www.tentree.com/collections/womens-t-shirts-tanks1/2341/3995/products/TCW4834-0164.jpg?v=1634833601', 'DEEP JUNGLE', 'S', 'https://www.tentree.com/collections/womens-t-shirts-tanks/products/womens-lorax-t-shirt?METEORITE BLACK', 40.0], ['The Lorax T-Shirt', 'https://www.tentree.com/collections/womens-t-shirts-tanks1/2341/3995/products/TCW4834-0164.jpg?v=1634833601', 'DEEP JUNGLE', 'M', 'https://www.tentree.com/collections/womens-t-shirts-tanks/products/womens-lorax-t-shirt?METEORITE BLACK', 40.0], ['The Lorax T-Shirt', 'https://www.tentree.com/collections/womens-t-shirts-tanks1/2341/3995/products/TCW4834-0164.jpg?v=1634833601', 'DEEP JUNGLE', 'L', 'https://www.tentree.com/collections/womens-t-shirts-tanks/products/womens-lorax-t-shirt?METEORITE BLACK', 40.0], ['The Lorax T-Shirt', 'https://www.tentree.com/collections/womens-t-shirts-tanks1/2341/3995/products/TCW4834-0164.jpg?v=1634833601', 'DEEP JUNGLE', 'XL', 'https://www.tentree.com/collections/womens-t-shirts-tanks/products/womens-lorax-t-shirt?METEORITE BLACK', 40.0], ['Hemp V-Neck T-Shirt', 'https://www.tentree.com/collections/womens-t-shirts-tanks1/2341/3995/products/TCW2673-20131.jpg?v=1626891452', 'MULBERRY', 'XS', 'https://www.tentree.com/collections/womens-t-shirts-tanks/products/womens-lorax-t-shirt?METEORITE BLACK', 40.0], ['Hemp V-Neck T-Shirt', 'https://www.tentree.com/collections/womens-t-shirts-tanks1/2341/3995/products/TCW2673-20131.jpg?v=1626891452', 'MULBERRY', 'S', 'https://www.tentree.com/collections/womens-t-shirts-tanks/products/womens-lorax-t-shirt?METEORITE BLACK', 40.0], ['Hemp V-Neck T-Shirt', 'https://www.tentree.com/collections/womens-t-shirts-tanks1/2341/3995/products/TCW2673-20131.jpg?v=1626891452', 'MULBERRY', 'M', 'https://www.tentree.com/collections/womens-t-shirts-tanks/products/womens-lorax-t-shirt?METEORITE BLACK', 40.0], ['Hemp V-Neck T-Shirt', 'https://www.tentree.com/collections/womens-t-shirts-tanks1/2341/3995/products/TCW2673-20131.jpg?v=1626891452', 'MULBERRY', 'L', 'https://www.tentree.com/collections/womens-t-shirts-tanks/products/womens-lorax-t-shirt?METEORITE BLACK', 40.0], ['Hemp V-Neck T-Shirt', 'https://www.tentree.com/collections/womens-t-shirts-tanks1/2341/3995/products/TCW2673-20131.jpg?v=1626891452', 'MULBERRY', 'XL', 'https://www.tentree.com/collections/womens-t-shirts-tanks/products/womens-lorax-t ...
# 230

# %%
df_womens_tt
# Out:
#                          name  ...                                        ethical_url
# 0           The Lorax T-Shirt  ...  <a href="/pages/ethical-manufacturing" target=...
# 1           The Lorax T-Shirt  ...  <a href="/pages/ethical-manufacturing" target=...
# 2           The Lorax T-Shirt  ...  <a href="/pages/ethical-manufacturing" target=...
# 3           The Lorax T-Shirt  ...  <a href="/pages/ethical-manufacturing" target=...
# 4           The Lorax T-Shirt  ...  <a href="/pages/ethical-manufacturing" target=...
# ..                        ...  ...                                                ...
# 225  Peaks Embroidery T-Shirt  ...  <a href="/pages/ethical-manufacturing" target=...
# 226  Peaks Embroidery T-Shirt  ...  <a href="/pages/ethical-manufacturing" target=...
# 227  Peaks Embroidery T-Shirt  ...  <a href="/pages/ethical-manufacturing" target=...
# 228  Peaks Embroidery T-Shirt  ...  <a href="/pages/ethical-manufacturing" target=...
# 229  Peaks Embroidery T-Shirt  ...  <a href="/pages/ethical-manufacturing" target=...
#
# [230 rows x 10 columns]

# %%
df_womens_tt['gender'] = "womens"

# %%
df_womens_tt
# Out:
#                          name  ...  gender
# 0           The Lorax T-Shirt  ...  womens
# 1           The Lorax T-Shirt  ...  womens
# 2           The Lorax T-Shirt  ...  womens
# 3           The Lorax T-Shirt  ...  womens
# 4           The Lorax T-Shirt  ...  womens
# ..                        ...  ...     ...
# 225  Peaks Embroidery T-Shirt  ...  womens
# 226  Peaks Embroidery T-Shirt  ...  womens
# 227  Peaks Embroidery T-Shirt  ...  womens
# 228  Peaks Embroidery T-Shirt  ...  womens
# 229  Peaks Embroidery T-Shirt  ...  womens
#
# [230 rows x 11 columns]

# %%
df_womens_tt[['material1', 'material2', 'material3']] = df_womens_tt['materials'].str.split(",", expand=True)

# %%
df_womens_tt
# Out:
#                          name  ...            material3
# 0           The Lorax T-Shirt  ...   25% Organic Cotton
# 1           The Lorax T-Shirt  ...   25% Organic Cotton
# 2           The Lorax T-Shirt  ...   25% Organic Cotton
# 3           The Lorax T-Shirt  ...   25% Organic Cotton
# 4           The Lorax T-Shirt  ...   25% Organic Cotton
# ..                        ...  ...                  ...
# 225  Peaks Embroidery T-Shirt  ...   25% Organic Cotton
# 226  Peaks Embroidery T-Shirt  ...   25% Organic Cotton
# 227  Peaks Embroidery T-Shirt  ...   25% Organic Cotton
# 228  Peaks Embroidery T-Shirt  ...   25% Organic Cotton
# 229  Peaks Embroidery T-Shirt  ...   25% Organic Cotton
#
# [230 rows x 14 columns]

# %% [markdown]
# Reorder womens df

# %%
df_womens_tt = df_womens_tt[['name', 'image_url', 'color', 'size', 'url', 'price', 'fit_features', 'materials', 'wash_dir', 'ethical_url', 'gender', 'material1', 'material2', 'material3']]

# %%
df_womens_tt
# Out:
#                          name  ...            material3
# 0           The Lorax T-Shirt  ...   25% Organic Cotton
# 1           The Lorax T-Shirt  ...   25% Organic Cotton
# 2           The Lorax T-Shirt  ...   25% Organic Cotton
# 3           The Lorax T-Shirt  ...   25% Organic Cotton
# 4           The Lorax T-Shirt  ...   25% Organic Cotton
# ..                        ...  ...                  ...
# 225  Peaks Embroidery T-Shirt  ...   25% Organic Cotton
# 226  Peaks Embroidery T-Shirt  ...   25% Organic Cotton
# 227  Peaks Embroidery T-Shirt  ...   25% Organic Cotton
# 228  Peaks Embroidery T-Shirt  ...   25% Organic Cotton
# 229  Peaks Embroidery T-Shirt  ...   25% Organic Cotton
#
# [230 rows x 14 columns]

# %% [markdown]
# Combining dfs (stack)

# %%
total_tentree = pd.concat([df_mens_tt,df_womens_tt], ignore_index=True)

# %%
total_tentree
# Out:
#                          name  ...            material3
# 0        Lorax Unless T-Shirt  ...   25% Organic Cotton
# 1        Lorax Unless T-Shirt  ...   25% Organic Cotton
# 2        Lorax Unless T-Shirt  ...   25% Organic Cotton
# 3        Lorax Unless T-Shirt  ...   25% Organic Cotton
# 4        Lorax Unless T-Shirt  ...   25% Organic Cotton
# ..                        ...  ...                  ...
# 435  Peaks Embroidery T-Shirt  ...   25% Organic Cotton
# 436  Peaks Embroidery T-Shirt  ...   25% Organic Cotton
# 437  Peaks Embroidery T-Shirt  ...   25% Organic Cotton
# 438  Peaks Embroidery T-Shirt  ...   25% Organic Cotton
# 439  Peaks Embroidery T-Shirt  ...   25% Organic Cotton
#
# [440 rows x 14 columns]

# %% [markdown]
# df to csv

# %%
total_tentree.to_csv('tentree.csv')

# %%
# !cp tentree.csv "drive/My Drive/Drexel/DSCI591/data"
