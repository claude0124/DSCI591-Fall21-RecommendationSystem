# %% [markdown]
# This note book is duplicate of vgg16.ipynb It is used to run masked_image_data foloder

# %% [markdown]
# How to install Keras in local: https://oindrilasen.com/2021/02/how-to-install-and-import-keras-in-anaconda-jupyter-notebooks/

# %%
from keras.applications.vgg16 import preprocess_input, VGG16
from keras.preprocessing import image as kimage
import keras

import os
import re
import numpy as np
from PIL import Image
# %matplotlib inline
import matplotlib.pyplot as plt
import pickle
from tqdm import tqdm
# Out:
# Using TensorFlow backend.

# %%
vggModel = VGG16(weights='imagenet', include_top=False)
# Out:
# WARNING:tensorflow:From /opt/anaconda3/envs/keras_env/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /opt/anaconda3/envs/keras_env/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
img_path = "../data/masked_image_data"

# %%
# Get unordered list of images
file_lst = os.listdir(img_path)

# %%
# Order list of images in human sorting based on the first unique index in filename
def atoi(text):
    return int(text) if text.isdigit() else text

def natural_keys(text):
    '''
    alist.sort(key=natural_keys) sorts in human order
    http://nedbatchelder.com/blog/200712/human_sorting.html
    (See Toothy's implementation in the comments)
    '''
    return [ atoi(c) for c in re.split(r'(\d+)', text) ]

file_lst.sort(key=natural_keys)

# %%
[file for file in file_lst if not file.endswith("png")]
# Out:
# ['.DS_Store']

# %%
file_lst.remove('.DS_Store')
[file for file in file_lst if not file.endswith("png")]
# Out:
# []

# %%
k = len(file_lst)
image = [0]*k
x = [0]*k
i=0
error_image = []
with tqdm(total=k) as pbar:
    for fileName in file_lst:
        pbar.update(1)
        try:
            image[i] = kimage.load_img(os.path.join(img_path, fileName), target_size=(300,300))
        except:
            image[i] = image[i-1]
            error_image.append(fileName)
        x[i] = kimage.img_to_array(image[i])
        x[i] = np.expand_dims(x[i], axis=0)
        # preprocess_input: The images are converted from RGB to BGR, then each color channel 
        # is zero-centered with respect to the ImageNet dataset, without scaling.
        x[i] = preprocess_input(x[i])
        i += 1
print(error_image)
# Out:
# 100%|██████████| 1419/1419 [00:23<00:00, 59.50it/s]
# []

# %%
# Example of testing one random image
# Original image
w, h = image[0].size
print(f"width{w}, height{h}")
image[0]
# Out:
# width300, height300
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7FAE9CE9BA90>

# %%
# The image below is preprocess, different from original image
t = x[0][0,:,:,:]
plt.imshow(t/255)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
if os.path.isfile("similarity_deep_w_masked.pkl"):
    with open('similarity_deep_w_masked.pkl', 'rb') as openfile:
        similarity_deep = pickle.load(openfile)
else:
    prediction = [0]*k
    # got 41472 from ValueError message from prediction[i]
    # ValueError: could not broadcast input array from shape (41472) into shape (45000)
    matrix_res = np.zeros([k, 41472])
    with tqdm(total=k) as pbar:
        for i in range(k):
            pbar.update(1)
            prediction[i] = vggModel.predict(x[i]).ravel()
            matrix_res[i,:] = prediction[i]
    
    similarity_deep = matrix_res.dot(matrix_res.T)
    norms = np.array([np.sqrt(np.diagonal(similarity_deep))])
    similarity_deep = similarity_deep / norms / norms.T
# Out:
#   0%|          | 0/1419 [00:00<?, ?it/s]
# WARNING:tensorflow:From /opt/anaconda3/envs/keras_env/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# 100%|██████████| 1419/1419 [1:02:08<00:00,  2.63s/it]

# %%
similarity_deep.shape
# Out:
# (1419, 1419)

# %%
with open('similarity_deep_w_masked.pkl', 'wb') as outp:
    pickle.dump(similarity_deep, outp)
with open('flatten_matrix_w_masked.pkl', 'wb') as outp:
    pickle.dump(matrix_res, outp)
# with open('similarity_deep_w_masked.pkl', 'rb') as openfile:
#     similarity_deep = pickle.load(openfile)

# %%
# create a dictionary index
idx = {}

for i in range(len(file_lst)):   
    idx[i] = file_lst[i]

# %%
# k indicate top ?, tshirt_input indicates original input to similarity matrix
k=5
tshirt_input = 19
maskedFileName = idx[tshirt_input]
top5 = np.argsort(similarity_deep[tshirt_input,:])[:-k-1:-1]
maskedFileName
# Out:
# 'masked_19.png'

# %%
# similarity score
print(similarity_deep[tshirt_input,top5])
# print image index
print(top5)
# Out:
# [1.         0.69337114 0.68603745 0.68253085 0.68183993]
# [ 19 143 100  16 139]

# %%
for idx in top5:
  display(image[idx])
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7FAE78C07F50>
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7FAE79B11C50>
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7FAE8906EFD0>
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7FAE89057E50>
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7FAE79B11A50>

# %%
# find cosine similarity between two vectors:
# import scipy
# vector1 = [1,2,3]
# vector2 = [3,2,1]
# cosine_similarity = 1 - scipy.spatial.distance.cosine(vector1, vector2)
# cosine_similarity
