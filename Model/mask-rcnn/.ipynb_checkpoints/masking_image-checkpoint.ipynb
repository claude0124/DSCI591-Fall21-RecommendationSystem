# %%
import os
import numpy as np
from PIL import Image
# %matplotlib inline
import matplotlib.pyplot as plt
import pickle
from tqdm import tqdm
# %pylab inline
import matplotlib.image as mpimg
import re
import cv2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Get lists of images and masks
image_path = '/Users/Claude/Documents/GitHub/DSCI591-Fall21-RecommendationSystem/data/image_data'
image_files = []
for root, dirs, files in os.walk(image_path):
    image_files.append(files)
    break
mask_files = []
mask_path = '/Users/Claude/Documents/GitHub/DSCI591-Fall21-RecommendationSystem/data/mask_pkls'
for root, dirs, files in os.walk(mask_path):
    mask_files.append(files)
    break

# %%
# Flatten the lists
image_files = [image for sublist in image_files for image in sublist]
mask_files = [mask for sublist in mask_files for mask in sublist]

# %%
print(f"There are {len(image_files)} image files and {len(mask_files)} mask pickle files")
# Out:
# There are 2834 image files and 2 mask pickle files

# %%
# What are these
mask_files
# Out:
# ['.DS_Store', '.gitignore']

# %%
# Pair the image with cooresponding mask
num_pattern = '(\d*)'

mask_image_pairs = {}
for mask_i in mask_files:
    if (mask_i == ".DS_Store") or (mask_i == ".gitignore"):
        continue
    mask_ID = re.match(num_pattern, mask_i).group()

    for image_i in image_files:
        if (image_i == ".DS_Store") or (image_i == ".gitignore"):
            continue
        image_ID = re.match(num_pattern, image_i).group()
        if mask_ID == image_ID:
            mask_image_pairs[image_ID] = (image_i, mask_i)
            break

# %%
k = len(mask_image_pairs)
print(f"Total pairs are: {len(mask_image_pairs)}")
# Out:
# Total pairs are: 1419

# %%
def mask_image(image_i, mask_i, image_path, mask_path):

    # Load image
    image = plt.imread(os.path.join(image_path, image_i), 0)

    # Load mask
    with open(mask_path+'/'+mask_i, 'rb') as file:
        mask_dict = pickle.load(file)

    #separate into r, g, b instances and mask each one
    r, g, b = np.ma.masked_where(mask_dict[0]['masks'][:,:,0]==0, image[:,:,0]), np.ma.masked_where(mask_dict[0]['masks'][:,:,0]==0, image[:,:,1]), np.ma.masked_where(mask_dict[0]['masks'][:,:,0]==0, image[:,:,2])

    #create initial blank mask 
    mask = np.zeros(image.shape, dtype=np.uint8)
    mask = cv2.circle(mask, (260, 300), 225, (255,255,255), -1) 

    # Mask input image with binary mask
    result = cv2.bitwise_and(image, mask)

    # Color background white
    result[mask==0] = 255 # Optional

    # image np array applied with mask
    img = result * ~r.mask[..., None]

    # Use image_i as unique ID for each file
    num_pattern = "(\d*)"
    file_ID = re.match(num_pattern, image_i).group()
    folder_address = "/Users/Claude/Documents/GitHub/DSCI591-Fall21-RecommendationSystem/data/masked_image_data"
    file_name = "masked_" + file_ID + ".png"

    # Save the output in the data/masked_image_data
    im = Image.fromarray(img)
    im.save(os.path.join(folder_address, file_name))

# %%
# Iterate through the image and mask pairs and combine them together
k = len(mask_image_pairs)
with tqdm(total=k) as pbar:
    for i in mask_image_pairs:
        pbar.update(1)
        image_i, mask_i = mask_image_pairs[i]
        try:
            mask_image(image_i, mask_i, image_path, mask_path)
        except Exception as e:
            print(e)
            print(image_i, mask_i)

# #load examples

# image = plt.imread(os.path.join(image_path, image_i), 0)
# Out:
# 100%|██████████| 1419/1419 [03:20<00:00,  7.06it/s]

# %%
result_files = []
result_path = '/Users/Claude/Documents/GitHub/DSCI591-Fall21-RecommendationSystem/data/masked_image_data'
for root, dirs, files in os.walk(result_path):
    result_files.append(files)
    break
result_files = [result for sublist in result_files for result in sublist]

# %% [markdown]
# Move masked images from masked_image_data folder and the rest of unmasked image from image_data folder to mixed_image_data folder

# %%
import shutil
masked_path = "/Users/Claude/Documents/GitHub/DSCI591-Fall21-RecommendationSystem/data/masked_image_data"
masked_lst = os.listdir(masked_path)
masked_id_lst = []
num_pattern = '(\d*)'
for filename in masked_lst:
    if (filename == ".DS_Store") or (filename == ".gitignore"):
        continue
    ID = re.match(num_pattern, filename[7:]).group()
    masked_id_lst.append(ID)

# %%
masked_lst
# Out:
# ['masked_2619.png',
#  'masked_1476.png',
#  'masked_1462.png',
#  'masked_69.png',
#  'masked_202.png',
#  'masked_2625.png',
#  'masked_41.png',
#  'masked_2143.png',
#  'masked_1338.png',
#  'masked_2631.png',
#  'masked_2802.png',
#  'masked_2816.png',
#  'masked_82.png',
#  'masked_96.png',
#  'masked_1674.png',
#  'masked_1660.png',
#  'masked_2341.png',
#  'masked_2427.png',
#  'masked_2433.png',
#  'masked_2396.png',
#  'masked_160.png',
#  'masked_174.png',
#  'masked_2553.png',
#  'masked_2547.png',
#  'masked_148.png',
#  'masked_1728.png',
#  'masked_2221.png',
#  'masked_2590.png',
#  'masked_362.png',
#  'masked_404.png',
#  'masked_410.png',
#  'masked_376.png',
#  'masked_2751.png',
#  'masked_438.png',
#  'masked_2792.png',
#  'masked_2786.png',
#  'masked_389.png',
#  'masked_388.png',
#  'masked_2787.png',
#  'masked_2793.png',
#  'masked_2750.png',
#  'masked_2036.png',
#  'masked_439.png',
#  'masked_1517.png',
#  'masked_411.png',
#  'masked_377.png',
#  'masked_2778.png',
#  'masked_363.png',
#  'masked_1265.png',
#  'masked_405.png',
#  'masked_1503.png',
#  'masked_2585.png',
#  'masked_1926.png',
#  'masked_2591.png',
#  'masked_149.png',
#  'masked_2546.png',
#  'masked_2220.png',
#  'masked_1729.png',
#  'masked_2552.png',
#  'masked_175.png',
#  'masked_1715.png',
#  'masked_2208.png',
#  'masked_1701.png',
#  'masked_161.png',
#  'masked_2432.png',
#  'masked_2354.png',
#  'masked_1885.png',
#  'masked_1649.png',
#  'masked_2340.png',
#  'masked_2426.png',
#  'masked_1661.png',
#  'masked_1675.png',
#  'masked_1113.png',
#  'masked_97.png',
#  'masked_83.png',
#  'masked_2817.png',
#  'masked_54.png',
#  'masked_2630.png',
#  'masked_2142.png',
#  'masked_40.png',
#  'masked_68.png',
#  'masked_1463.png',
#  'masked_203.png',
#  'masked_217.png',
#  'masked_1477.png',
#  'masked_201.png',
#  'masked_1461.png',
#  'masked_1475.png',
#  'masked_215.png',
#  'masked_56.png',
#  'masked_42.png',
#  'masked_2815.png',
#  'masked_2801.png',
#  'masked_95.png',
#  'masked_81.png',
#  'masked_1663.png',
#  'masked_1677.png',
#  'masked_2356.png',
#  'masked_2430.png',
#  'masked_2342.png',
#  'masked_1893.png',
#  'masked_1844.png',
#  'masked_1850.png',
#  'masked_2578.png',
#  'masked_163.png',
#  'masked_1703.png',
#  'masked_2222.png',
#  'masked_2544.png',
#  'masked_2550.png',
#  'masked_2236.png',
#  'masked_1918.png',
#  'masked_1930.png',
#  'masked_188.png',
#  'masked_2587.png',
#  'masked_375.png',
#  'masked_413.png',
#  'masked_1515.png',
#  'masked_1501.png',
#  'masked_407.png',
#  'masked_361.png',
#  'masked_349.png',
#  'masked_2746.png',
#  'masked_1529.png',
#  'masked_2034.png',
#  'masked_2961.png',
#  'masked_2975.png',
#  'masked_2785.png',
#  'masked_2791.png',
#  'masked_2949.png',
#  'masked_2790.png',
#  'masked_2960.png',
#  'masked_2035.png',
#  'masked_2747.png',
#  'masked_1528.png',
#  'masked_1500.png',
#  'masked_360.png',
#  'masked_374.png',
#  'masked_2586.png',
#  'masked_189.png',
#  'masked_2551.png',
#  'masked_2237.png',
#  'masked_2223.png',
#  'masked_2545.png',
#  'masked_162.png',
#  'masked_1702.png',
#  'masked_1716.png',
#  'masked_2579.png',
#  'masked_2380.png',
#  'masked_1851.png',
#  'masked_1689.png',
#  'masked_2394.png',
#  'masked_2343.png',
#  'masked_2357.png',
#  'masked_1886.png',
#  'masked_2419.png',
#  'masked_1676.png',
#  'masked_1662.png',
#  'masked_80.png',
#  'masked_2182.png',
#  'masked_2828.png',
#  'masked_94.png',
#  'masked_2800.png',
#  'masked_2814.png',
#  'masked_2141.png',
#  'masked_43.png',
#  'masked_1448.png',
#  'masked_228.png',
#  'masked_2627.png',
#  'masked_57.png',
#  'masked_1474.png',
#  'masked_214.png',
#  'masked_200.png',
#  'masked_1460.png',
#  'masked_53.png',
#  'masked_2151.png',
#  'masked_238.png',
#  'masked_2637.png',
#  'masked_2623.png',
#  'masked_47.png',
#  'masked_1464.png',
#  'masked_204.png',
#  'masked_210.png',
#  'masked_1470.png',
#  'masked_90.png',
#  'masked_2186.png',
#  'masked_84.png',
#  'masked_2810.png',
#  'masked_2435.png',
#  'masked_2353.png',
#  'masked_2347.png',
#  'masked_1896.png',
#  'masked_1666.png',
#  'masked_1672.png',
#  'masked_2390.png',
#  'masked_1699.png',
#  'masked_1855.png',
#  'masked_2384.png',
#  'masked_2541.png',
#  'masked_2227.png',
#  'masked_2555.png',
#  'masked_172.png',
#  'masked_1712.png',
#  'masked_1706.png',
#  'masked_2569.png',
#  'masked_166.png',
#  'masked_2582.png',
#  'masked_2596.png',
#  'masked_199.png',
#  '.DS_Store',
#  'masked_358.png',
#  'masked_1538.png',
#  'masked_416.png',
#  'masked_370.png',
#  'masked_364.png',
#  'masked_402.png',
#  'masked_1504.png',
#  'masked_1289.png',
#  'masked_2970.png',
#  'masked_2971.png',
#  'masked_1288.png',
#  'masked_1505.png',
#  'masked_1511.png',
#  'masked_417.png',
#  'masked_371.png',
#  'masked_359.png',
#  'masked_2756.png',
#  'masked_1539.png',
#  'masked_1908.png',
#  'masked_198.png',
#  'masked_1707.png',
#  'masked_167.png',
#  'masked_2568.png',
#  'masked_173.png',
#  'masked_1713.png',
#  'masked_2232.png',
#  'masked_2554.png',
#  'masked_2540.png',
#  'masked_2226.png',
#  'masked_1868.png',
#  'masked_2385.png',
#  'masked_1840.png',
#  'masked_1698.png',
#  'masked_2391.png',
#  'masked_1673.png',
#  'masked_2408.png',
#  'masked_1667.png',
#  'masked_2346.png',
#  'masked_2420.png',
#  'masked_1129.png',
#  'masked_1883.png',
#  'masked_2805.png',
#  'masked_2839.png',
#  'masked_85.png',
#  'masked_91.png',
#  'masked_211.png',
#  'masked_1471.png',
#  'masked_1465.png',
#  'masked_205.png',
#  'masked_2622.png',
#  'masked_46.png',
#  'masked_1459.png',
#  'masked_52.png',
#  'masked_2636.png',
#  'masked_239.png',
#  'masked_44.png',
#  'masked_2620.png',
#  'masked_1329.png',
#  'masked_2634.png',
#  'masked_50.png',
#  'masked_78.png',
#  'masked_213.png',
#  'masked_2608.png',
#  'masked_207.png',
#  'masked_1467.png',
#  'masked_87.png',
#  'masked_1498.png',
#  'masked_93.png',
#  'masked_2807.png',
#  'masked_1881.png',
#  'masked_1659.png',
#  'masked_2378.png',
#  'masked_2387.png',
#  'masked_159.png',
#  'masked_2556.png',
#  'masked_2230.png',
#  'masked_1739.png',
#  'masked_2224.png',
#  'masked_2542.png',
#  'masked_165.png',
#  'masked_2218.png',
#  'masked_1711.png',
#  'masked_171.png',
#  'masked_2595.png',
#  'masked_1922.png',
#  'masked_429.png',
#  'masked_1507.png',
#  'masked_367.png',
#  'masked_373.png',
#  'masked_415.png',
#  'masked_1513.png',
#  'masked_398.png',
#  'masked_2973.png',
#  'masked_2966.png',
#  'masked_2972.png',
#  'masked_2782.png',
#  'masked_2796.png',
#  'masked_399.png',
#  'masked_372.png',
#  'masked_1512.png',
#  'masked_1506.png',
#  'masked_400.png',
#  'masked_366.png',
#  'masked_2741.png',
#  'masked_428.png',
#  'masked_2580.png',
#  'masked_2594.png',
#  'masked_1710.png',
#  'masked_2219.png',
#  'masked_170.png',
#  'masked_164.png',
#  'masked_1704.png',
#  'masked_2225.png',
#  'masked_2543.png',
#  'masked_2557.png',
#  'masked_158.png',
#  'masked_1738.png',
#  'masked_2231.png',
#  'masked_2392.png',
#  'masked_2386.png',
#  'masked_2379.png',
#  'masked_2351.png',
#  'masked_1658.png',
#  'masked_1880.png',
#  'masked_2437.png',
#  'masked_2423.png',
#  'masked_1894.png',
#  'masked_92.png',
#  'masked_1499.png',
#  'masked_86.png',
#  'masked_1300.png',
#  'masked_206.png',
#  'masked_2609.png',
#  'masked_1466.png',
#  'masked_1472.png',
#  'masked_79.png',
#  'masked_2635.png',
#  'masked_51.png',
#  'masked_2147.png',
#  'masked_45.png',
#  'masked_2621.png',
#  'masked_513.png',
#  'masked_1415.png',
#  'masked_275.png',
#  'masked_261.png',
#  'masked_1401.png',
#  'masked_507.png',
#  'masked_22.png',
#  'masked_2120.png',
#  'masked_1429.png',
#  'masked_249.png',
#  'masked_2646.png',
#  'masked_2652.png',
#  'masked_36.png',
#  'masked_2861.png',
#  'masked_2685.png',
#  'masked_1398.png',
#  'masked_2849.png',
#  'masked_2691.png',
#  'masked_1617.png',
#  'masked_1603.png',
#  'masked_2450.png',
#  'masked_1818.png',
#  'masked_2487.png',
#  'masked_2493.png',
#  'masked_103.png',
#  'masked_1763.png',
#  'masked_2518.png',
#  'masked_117.png',
#  'masked_2530.png',
#  'masked_2256.png',
#  'masked_2524.png',
#  'masked_1788.png',
#  'masked_1561.png',
#  'masked_467.png',
#  'masked_2068.png',
#  'masked_301.png',
#  'masked_315.png',
#  'masked_473.png',
#  'masked_1575.png',
#  'masked_1549.png',
#  'masked_2040.png',
#  'masked_498.png',
#  'masked_2097.png',
#  'masked_2083.png',
#  'masked_2082.png',
#  'masked_499.png',
#  'masked_1548.png',
#  'masked_2733.png',
#  'masked_314.png',
#  'masked_472.png',
#  'masked_1574.png',
#  'masked_300.png',
#  'masked_2280.png',
#  'masked_2525.png',
#  'masked_2531.png',
#  'masked_2257.png',
#  'masked_1776.png',
#  'masked_116.png',
#  'masked_2519.png',
#  'masked_102.png',
#  'masked_1004.png',
#  'masked_1762.png',
#  'masked_923.png',
#  'masked_2492.png',
#  'masked_2337.png',
#  'masked_2451.png',
#  'masked_2445.png',
#  'masked_2323.png',
#  'masked_2479.png',
#  'masked_1170.png',
#  'masked_1616.png',
#  'masked_2690.png',
#  'masked_2848.png',
#  'masked_1399.png',
#  'masked_2684.png',
#  'masked_2135.png',
#  'masked_37.png',
#  'masked_1428.png',
#  'masked_23.png',
#  'masked_2647.png',
#  'masked_248.png',
#  'masked_1366.png',
#  'masked_260.png',
#  'masked_506.png',
#  'masked_512.png',
#  'masked_1414.png',
#  'masked_274.png',
#  'masked_1372.png',
#  'masked_504.png',
#  'masked_262.png',
#  'masked_1364.png',
#  'masked_276.png',
#  'masked_510.png',
#  'masked_35.png',
#  'masked_2651.png',
#  'masked_1358.png',
#  'masked_21.png',
#  'masked_2862.png',
#  'masked_289.png',
#  'masked_1600.png',
#  'masked_1614.png',
#  'masked_2453.png',
#  'masked_2335.png',
#  'masked_1628.png',
#  'masked_2447.png',
#  'masked_2490.png',
#  'masked_1199.png',
#  'masked_1827.png',
#  'masked_114.png',
#  'masked_1774.png',
#  'masked_2269.png',
#  'masked_1760.png',
#  'masked_1006.png',
#  'masked_100.png',
#  'masked_2527.png',
#  'masked_2241.png',
#  'masked_2533.png',
#  'masked_2282.png',
#  'masked_1576.png',
#  'masked_470.png',
#  'masked_316.png',
#  'masked_302.png',
#  'masked_464.png',
#  'masked_1562.png',
#  'masked_2725.png',
#  'masked_1238.png',
#  'masked_2057.png',
#  'masked_458.png',
#  'masked_2902.png',
#  'masked_1589.png',
#  'masked_1588.png',
#  'masked_2730.png',
#  'masked_1239.png',
#  'masked_459.png',
#  'masked_2042.png',
#  'masked_303.png',
#  'masked_465.png',
#  'masked_1563.png',
#  'masked_1577.png',
#  'masked_471.png',
#  'masked_2718.png',
#  'masked_317.png',
#  'masked_2283.png',
#  'masked_2254.png',
#  'masked_2532.png',
#  'masked_2526.png',
#  'masked_129.png',
#  'masked_1749.png',
#  'masked_2240.png',
#  'masked_2268.png',
#  'masked_101.png',
#  'masked_115.png',
#  'masked_934.png',
#  'masked_2485.png',
#  'masked_1826.png',
#  'masked_2320.png',
#  'masked_1629.png',
#  'masked_2446.png',
#  'masked_2452.png',
#  'masked_1615.png',
#  'masked_2308.png',
#  'masked_1601.png',
#  'masked_2863.png',
#  'masked_2644.png',
#  'masked_20.png',
#  'masked_34.png',
#  'masked_1359.png',
#  'masked_2888.png',
#  'masked_2650.png',
#  'masked_277.png',
#  'masked_2678.png',
#  'masked_511.png',
#  'masked_505.png',
#  'masked_1403.png',
#  'masked_263.png',
#  'masked_1365.png',
#  'masked_2654.png',
#  'masked_30.png',
#  'masked_24.png',
#  'masked_529.png',
#  'masked_2898.png',
#  'masked_1361.png',
#  'masked_1407.png',
#  'masked_501.png',
#  'masked_1413.png',
#  'masked_18.png',
#  'masked_273.png',
#  'masked_1375.png',
#  'masked_298.png',
#  'masked_2683.png',
#  'masked_2330.png',
#  'masked_1639.png',
#  'masked_2456.png',
#  'masked_2442.png',
#  'masked_2324.png',
#  'masked_1605.png',
#  'masked_1611.png',
#  'masked_2495.png',
#  'masked_8.png',
#  'masked_2481.png',
#  'masked_918.png',
#  'masked_2522.png',
#  'masked_2536.png',
#  'masked_139.png',
#  'masked_1759.png',
#  'masked_2250.png',
#  'masked_1771.png',
#  'masked_2278.png',
#  'masked_111.png',
#  'masked_105.png',
#  'masked_2720.png',
#  'masked_449.png',
#  'masked_2052.png',
#  'masked_313.png',
#  'masked_475.png',
#  'masked_1573.png',
#  'masked_1567.png',
#  'masked_461.png',
#  'masked_2708.png',
#  'masked_307.png',
#  'masked_1598.png',
#  'masked_1599.png',
#  'masked_2084.png',
#  'masked_1566.png',
#  'masked_460.png',
#  'masked_306.png',
#  'masked_2709.png',
#  'masked_312.png',
#  'masked_474.png',
#  'masked_1572.png',
#  'masked_2053.png',
#  'masked_2721.png',
#  'masked_448.png',
#  'masked_104.png',
#  'masked_2279.png',
#  'masked_1770.png',
#  'masked_110.png',
#  'masked_138.png',
#  'masked_1758.png',
#  'masked_2523.png',
#  'masked_2480.png',
#  'masked_1189.png',
#  'masked_9.png',
#  'masked_2494.png',
#  'masked_1610.png',
#  'masked_1604.png',
#  'masked_2443.png',
#  'masked_2331.png',
#  'masked_2457.png',
#  'masked_2866.png',
#  'masked_2696.png',
#  'masked_19.png',
#  'masked_514.png',
#  'masked_1412.png',
#  'masked_272.png',
#  'masked_1374.png',
#  'masked_2669.png',
#  'masked_1360.png',
#  'masked_266.png',
#  'masked_1406.png',
#  'masked_528.png',
#  'masked_25.png',
#  'masked_2899.png',
#  'masked_2641.png',
#  'masked_1348.png',
#  'masked_2655.png',
#  'masked_2133.png',
#  'masked_31.png',
#  'masked_27.png',
#  'masked_2131.png',
#  'masked_258.png',
#  'masked_1376.png',
#  'masked_270.png',
#  'masked_1410.png',
#  'masked_516.png',
#  'masked_502.png',
#  'masked_1362.png',
#  'masked_2858.png',
#  'masked_2455.png',
#  'masked_2333.png',
#  'masked_1612.png',
#  'masked_2469.png',
#  'masked_1606.png',
#  'masked_2482.png',
#  'masked_2496.png',
#  'masked_927.png',
#  'masked_1809.png',
#  'masked_2253.png',
#  'masked_2535.png',
#  'masked_2521.png',
#  'masked_106.png',
#  'masked_2509.png',
#  'masked_112.png',
#  'masked_1014.png',
#  'masked_338.png',
#  'masked_2045.png',
#  'masked_2723.png',
#  'masked_304.png',
#  'masked_1564.png',
#  'masked_2079.png',
#  'masked_1570.png',
#  'masked_476.png',
#  'masked_310.png',
#  'masked_489.png',
#  'masked_2938.png',
#  'masked_488.png',
#  'masked_2087.png',
#  'masked_477.png',
#  'masked_2078.png',
#  'masked_311.png',
#  'masked_305.png',
#  'masked_463.png',
#  'masked_1565.png',
#  'masked_2736.png',
#  'masked_339.png',
#  'masked_1559.png',
#  'masked_1798.png',
#  'masked_113.png',
#  'masked_1015.png',
#  'masked_1767.png',
#  'masked_2508.png',
#  'masked_107.png',
#  'masked_2520.png',
#  'masked_2246.png',
#  'masked_2534.png',
#  'masked_1808.png',
#  'masked_2497.png',
#  'masked_1820.png',
#  'masked_2483.png',
#  'masked_2468.png',
#  'masked_1607.png',
#  'masked_1613.png',
#  'masked_2454.png',
#  'masked_2332.png',
#  'masked_2326.png',
#  'masked_2871.png',
#  'masked_2865.png',
#  'masked_2695.png',
#  'masked_1388.png',
#  'masked_2859.png',
#  'masked_503.png',
#  'masked_265.png',
#  'masked_1363.png',
#  'masked_1377.png',
#  'masked_271.png',
#  'masked_2118.png',
#  'masked_1411.png',
#  'masked_517.png',
#  'masked_32.png',
#  'masked_259.png',
#  'masked_2656.png',
#  'masked_2642.png',
#  'masked_26.png',
#  'masked_1434.png',
#  'masked_532.png',
#  'masked_1352.png',
#  'masked_254.png',
#  'masked_2883.png',
#  'masked_240.png',
#  'masked_526.png',
#  'masked_2129.png',
#  'masked_1408.png',
#  'masked_2101.png',
#  'masked_2673.png',
#  'masked_17.png',
#  'masked_2115.png',
#  'masked_2840.png',
#  'masked_297.png',
#  'masked_1385.png',
#  'masked_2854.png',
#  'masked_2459.png',
#  'masked_1636.png',
#  'masked_1622.png',
#  'masked_2317.png',
#  'masked_7.png',
#  'masked_1839.png',
#  'masked_1811.png',
#  'masked_1024.png',
#  'masked_1742.png',
#  'masked_136.png',
#  'masked_2539.png',
#  'masked_1018.png',
#  'masked_2511.png',
#  'masked_2277.png',
#  'masked_2505.png',
#  'masked_1795.png',
#  'masked_2049.png',
#  'masked_446.png',
#  'masked_334.png',
#  'masked_452.png',
#  'masked_2075.png',
#  'masked_2713.png',
#  'masked_308.png',
#  'masked_2707.png',
#  'masked_1568.png',
#  'masked_1583.png',
#  'masked_485.png',
#  'masked_2920.png',
#  'masked_491.png',
#  'masked_1597.png',
#  'masked_2909.png',
#  'masked_490.png',
#  'masked_1596.png',
#  'masked_1582.png',
#  'masked_484.png',
#  'masked_2935.png',
#  'masked_2706.png',
#  'masked_2060.png',
#  'masked_335.png',
#  'masked_1555.png',
#  'masked_453.png',
#  'masked_447.png',
#  'masked_1541.png',
#  'masked_2048.png',
#  'masked_321.png',
#  'masked_137.png',
#  'masked_1743.png',
#  'masked_1804.png',
#  'masked_1810.png',
#  'masked_6.png',
#  'masked_2316.png',
#  'masked_1623.png',
#  'masked_1637.png',
#  'masked_2855.png',
#  'masked_1384.png',
#  'masked_282.png',
#  'masked_296.png',
#  'masked_1390.png',
#  'masked_2699.png',
#  'masked_2841.png',
#  'masked_2672.png',
#  'masked_16.png',
#  'masked_2100.png',
#  'masked_1409.png',
#  'masked_269.png',
#  'masked_2666.png',
#  'masked_241.png',
#  'masked_2128.png',
#  'masked_527.png',
#  'masked_1435.png',
#  'masked_533.png',
#  'masked_1353.png',
#  'masked_1423.png',
#  'masked_525.png',
#  'masked_28.png',
#  'masked_1345.png',
#  'masked_243.png',
#  'masked_257.png',
#  'masked_1351.png',
#  'masked_2658.png',
#  'masked_531.png',
#  'masked_1437.png',
#  'masked_14.png',
#  'masked_2116.png',
#  'masked_519.png',
#  'masked_1379.png',
#  'masked_2664.png',
#  'masked_280.png',
#  'masked_1386.png',
#  'masked_2843.png',
#  'masked_1392.png',
#  'masked_294.png',
#  'masked_1621.png',
#  'masked_1635.png',
#  'masked_2472.png',
#  'masked_2314.png',
#  'masked_1609.png',
#  'masked_4.png',
#  'masked_2499.png',
#  'masked_1806.png',
#  'masked_914.png',
#  'masked_1812.png',
#  'masked_1755.png',
#  'masked_2248.png',
#  'masked_121.png',
#  'masked_109.png',
#  'masked_2260.png',
#  'masked_2512.png',
#  'masked_1796.png',
#  'masked_337.png',
#  'masked_1231.png',
#  'masked_1543.png',
#  'masked_2062.png',
#  'masked_2704.png',
#  'masked_2710.png',
#  'masked_479.png',
#  'masked_2076.png',
#  'masked_1594.png',
#  'masked_492.png',
#  'masked_1580.png',
#  'masked_2936.png',
#  'masked_2088.png',
#  'masked_487.png',
#  'masked_1581.png',
#  'masked_1595.png',
#  'masked_493.png',
#  'masked_2922.png',
#  'masked_2711.png',
#  'masked_478.png',
#  'masked_322.png',
#  'masked_1542.png',
#  'masked_444.png',
#  'masked_450.png',
#  'masked_1556.png',
#  'masked_336.png',
#  'masked_2739.png',
#  'masked_1783.png',
#  'masked_108.png',
#  'masked_2507.png',
#  'masked_2261.png',
#  'masked_1768.png',
#  'masked_1032.png',
#  'masked_134.png',
#  'masked_1754.png',
#  'masked_1813.png',
#  'masked_1807.png',
#  'masked_5.png',
#  'masked_2467.png',
#  'masked_2473.png',
#  'masked_1634.png',
#  'masked_1146.png',
#  'masked_1620.png',
#  'masked_1393.png',
#  'masked_295.png',
#  'masked_2856.png',
#  'masked_1387.png',
#  'masked_518.png',
#  'masked_15.png',
#  'masked_1378.png',
#  'masked_2881.png',
#  'masked_2659.png',
#  'masked_256.png',
#  'masked_530.png',
#  'masked_29.png',
#  'masked_524.png',
#  'masked_1344.png',
#  'masked_242.png',
#  'masked_11.png',
#  'masked_2113.png',
#  'masked_508.png',
#  'masked_2661.png',
#  'masked_1368.png',
#  'masked_2649.png',
#  'masked_2891.png',
#  'masked_246.png',
#  'masked_1340.png',
#  'masked_1426.png',
#  'masked_39.png',
#  'masked_1432.png',
#  'masked_534.png',
#  'masked_1354.png',
#  'masked_252.png',
#  'masked_1383.png',
#  'masked_285.png',
#  'masked_2852.png',
#  'masked_291.png',
#  'masked_1397.png',
#  'masked_1618.png',
#  'masked_2311.png',
#  'masked_2477.png',
#  'masked_2305.png',
#  'masked_1624.png',
#  'masked_1630.png',
#  'masked_2339.png',
#  'masked_1803.png',
#  'masked_1817.png',
#  'masked_1.png',
#  'masked_1195.png',
#  'masked_2265.png',
#  'masked_118.png',
#  'masked_2517.png',
#  'masked_2271.png',
#  'masked_2259.png',
#  'masked_1750.png',
#  'masked_130.png',
#  'masked_1022.png',
#  'masked_124.png',
#  'masked_1744.png',
#  'masked_1793.png',
#  'masked_1787.png',
#  'masked_2701.png',
#  'masked_468.png',
#  'masked_2073.png',
#  'masked_2715.png',
#  'masked_1552.png',
#  'masked_454.png',
#  'masked_1546.png',
#  'masked_326.png',
#  'masked_2098.png',
#  'masked_497.png',
#  'masked_1585.png',
#  'masked_483.png',
#  'masked_1584.png',
#  'masked_482.png',
#  'masked_1590.png',
#  'masked_441.png',
#  'masked_1547.png',
#  'masked_2728.png',
#  'masked_333.png',
#  'masked_1553.png',
#  'masked_455.png',
#  'masked_469.png',
#  'masked_2066.png',
#  'masked_1786.png',
#  'masked_1792.png',
#  'masked_1023.png',
#  'masked_125.png',
#  'masked_1745.png',
#  'masked_1751.png',
#  'masked_131.png',
#  'masked_2516.png',
#  'masked_119.png',
#  'masked_2264.png',
#  'masked_2502.png',
#  'masked_1194.png',
#  'masked_0.png',
#  'masked_1802.png',
#  'masked_1631.png',
#  'masked_1625.png',
#  'masked_2462.png',
#  'masked_1619.png',
#  'masked_290.png',
#  'masked_1396.png',
#  'masked_2847.png',
#  'masked_2853.png',
#  'masked_1382.png',
#  'masked_284.png',
#  'masked_1433.png',
#  'masked_535.png',
#  'masked_38.png',
#  'masked_253.png',
#  'masked_247.png',
#  'masked_1341.png',
#  'masked_2890.png',
#  'masked_2648.png',
#  'masked_521.png',
#  'masked_1427.png',
#  'masked_2106.png',
#  'masked_509.png',
#  'masked_2674.png',
#  'masked_2112.png',
#  'masked_10.png',
#  'masked_2662.png',
#  'masked_2104.png',
#  'masked_12.png',
#  'masked_2110.png',
#  'masked_1419.png',
#  'masked_279.png',
#  'masked_2676.png',
#  'masked_251.png',
#  ...]

# %%
img_path = "/Users/Claude/Documents/GitHub/DSCI591-Fall21-RecommendationSystem/data/image_data"
img_lst = os.listdir(img_path)
id_lst = []
for filename in img_lst:
    if (filename == ".DS_Store") or (filename == ".gitignore"):
        continue
    ID = re.match(num_pattern, filename).group()
    id_lst.append(ID)

# %%
id_lst
# Out:
# ['348',
#  '1804',
#  '1810',
#  '1186',
#  '412',
#  '374',
#  '1838',
#  '360',
#  '406',
#  '1192',
#  '1179',
#  '2470',
#  '2316',
#  '2302',
#  '1145',
#  '1623',
#  '1637',
#  '1151',
#  '2458',
#  '2869',
#  '638',
#  '176',
#  '2855',
#  '88',
#  '610',
#  '1384',
#  '1390',
#  '604',
#  '2841',
#  '2699',
#  '162',
#  '189',
#  '2114',
#  '2672',
#  '837',
#  '77',
#  '823',
#  '63',
#  '2666',
#  '2100',
#  '1409',
#  '2128',
#  '1421',
#  '2896',
#  '2882',
#  '1353',
#  '1435',
#  '980',
#  '758',
#  '2909',
#  '994',
#  '1596',
#  '2921',
#  '764',
#  '770',
#  '2935',
#  '1582',
#  '1569',
#  '2060',
#  '2706',
#  '943',
#  '957',
#  '2712',
#  '2074',
#  '1555',
#  '1233',
#  '1227',
#  '1541',
#  '2048',
#  '228',
#  '566',
#  '1794',
#  '200',
#  '214',
#  '1780',
#  '2289',
#  '572',
#  '599',
#  '2504',
#  '2262',
#  '2276',
#  '1019',
#  '2538',
#  '1031',
#  '1757',
#  '1743',
#  '1025',
#  '1742',
#  '1024',
#  '1030',
#  '2539',
#  '2277',
#  '1018',
#  '2511',
#  '2505',
#  '598',
#  '2263',
#  '2288',
#  '1781',
#  '215',
#  '567',
#  '201',
#  '1795',
#  '229',
#  '1226',
#  '2049',
#  '1540',
#  '1554',
#  '1232',
#  '2713',
#  '956',
#  '2075',
#  '2061',
#  '1568',
#  '942',
#  '2707',
#  '2934',
#  '771',
#  '1583',
#  '1597',
#  '765',
#  '2920',
#  '995',
#  '2908',
#  '759',
#  '981',
#  '1352',
#  '2883',
#  '1434',
#  '1420',
#  '2129',
#  '2897',
#  '2667',
#  '62',
#  '822',
#  '1408',
#  '2101',
#  '2115',
#  '188',
#  '76',
#  '836',
#  '2673',
#  '2698',
#  '2840',
#  '605',
#  '1391',
#  '163',
#  '177',
#  '1385',
#  '611',
#  '89',
#  '2854',
#  '639',
#  '2868',
#  '1636',
#  '2459',
#  '1150',
#  '1144',
#  '1622',
#  '2303',
#  '2471',
#  '1178',
#  '2317',
#  '361',
#  '1193',
#  '407',
#  '413',
#  '1187',
#  '1839',
#  '375',
#  '1811',
#  '1805',
#  '349',
#  '439',
#  '1813',
#  '1807',
#  '2498',
#  '405',
#  '1191',
#  '363',
#  '377',
#  '1185',
#  '411',
#  '2467',
#  '1608',
#  '2301',
#  '2315',
#  '388',
#  '2473',
#  '1152',
#  '1634',
#  '1620',
#  '2329',
#  '1146',
#  '149',
#  '161',
#  '1393',
#  '607',
#  '2842',
#  '2856',
#  '613',
#  '1387',
#  '175',
#  '2103',
#  '820',
#  '60',
#  '2665',
#  '2671',
#  '834',
#  '74',
#  '1378',
#  '2117',
#  '1436',
#  '2659',
#  '2881',
#  '1350',
#  '808',
#  '48',
#  '1344',
#  '2895',
#  '1422',
#  '997',
#  '983',
#  '2088',
#  '1581',
#  '773',
#  '2936',
#  '2922',
#  '767',
#  '1595',
#  '2077',
#  '1218',
#  '954',
#  '2711',
#  '2705',
#  '798',
#  '940',
#  '2063',
#  '1542',
#  '1224',
#  '968',
#  '1230',
#  '2739',
#  '1556',
#  '559',
#  '571',
#  '217',
#  '1783',
#  '1797',
#  '203',
#  '565',
#  '2275',
#  '2261',
#  '1768',
#  '2507',
#  '1026',
#  '2249',
#  '1740',
#  '1754',
#  '1032',
#  '1755',
#  '1033',
#  '1027',
#  '1741',
#  '2248',
#  '1769',
#  '2260',
#  '2506',
#  '2512',
#  '2274',
#  '202',
#  '1796',
#  '1782',
#  '216',
#  '2738',
#  '1231',
#  '1557',
#  '1543',
#  '969',
#  '1225',
#  '941',
#  '799',
#  '2704',
#  '2062',
#  '2076',
#  '2710',
#  '955',
#  '1219',
#  '766',
#  '2923',
#  '1594',
#  '1580',
#  '2089',
#  '2937',
#  '772',
#  '982',
#  '996',
#  '2894',
#  '1345',
#  '49',
#  '809',
#  '1423',
#  '1437',
#  '1351',
#  '2880',
#  '2658',
#  '1379',
#  '75',
#  '835',
#  '2670',
#  '2116',
#  '2102',
#  '2664',
#  '61',
#  '821',
#  '1386',
#  '612',
#  '2857',
#  '174',
#  '160',
#  '2843',
#  '606',
#  '1392',
#  '148',
#  '2328',
#  '1621',
#  '1147',
#  '1153',
#  '1635',
#  '389',
#  '2314',
#  '2472',
#  '2466',
#  '2300',
#  '1609',
#  '376',
#  '410',
#  '1184',
#  '1190',
#  '404',
#  '2499',
#  '362',
#  '1806',
#  '438',
#  '1812',
#  '366',
#  '400',
#  '1194',
#  '1180',
#  '414',
#  '2489',
#  '372',
#  '1816',
#  '428',
#  '1802',
#  '2338',
#  '1631',
#  '1157',
#  '1143',
#  '1625',
#  '399',
#  '2304',
#  '2462',
#  '2476',
#  '2310',
#  '1619',
#  '1396',
#  '602',
#  '2847',
#  '164',
#  '170',
#  '2853',
#  '616',
#  '1382',
#  '158',
#  '2884',
#  '819',
#  '1355',
#  '59',
#  '1433',
#  '1427',
#  '1341',
#  '2648',
#  '2890',
#  '825',
#  '1369',
#  '65',
#  '2660',
#  '2106',
#  '2112',
#  '2674',
#  '831',
#  '71',
#  '776',
#  '2933',
#  '1584',
#  '1590',
#  '2099',
#  '2927',
#  '762',
#  '992',
#  '986',
#  '2728',
#  '1221',
#  '1547',
#  '1553',
#  '1235',
#  '979',
#  '789',
#  '951',
#  '2714',
#  '2072',
#  '2066',
#  '2700',
#  '1209',
#  '945',
#  '212',
#  '1786',
#  '574',
#  '560',
#  '1792',
#  '206',
#  '548',
#  '1745',
#  '1023',
#  '1037',
#  '1751',
#  '2258',
#  '1779',
#  '2270',
#  '2516',
#  '2502',
#  '2264',
#  '2265',
#  '2271',
#  '1778',
#  '2517',
#  '1036',
#  '2259',
#  '1750',
#  '1744',
#  '1022',
#  '561',
#  '207',
#  '1793',
#  '1787',
#  '213',
#  '575',
#  '2067',
#  '944',
#  '1208',
#  '2701',
#  '2715',
#  '950',
#  '788',
#  '2073',
#  '1552',
#  '978',
#  '1234',
#  '1220',
#  '2729',
#  '1546',
#  '987',
#  '993',
#  '2098',
#  '1591',
#  '763',
#  '2926',
#  '2932',
#  '777',
#  '1585',
#  '2113',
#  '70',
#  '830',
#  '2675',
#  '2661',
#  '64',
#  '1368',
#  '824',
#  '2107',
#  '1426',
#  '2891',
#  '2649',
#  '1340',
#  '58',
#  '1354',
#  '818',
#  '2885',
#  '1432',
#  '159',
#  '171',
#  '1383',
#  '617',
#  '2852',
#  '2846',
#  '1397',
#  '165',
#  '2477',
#  '1618',
#  '2311',
#  '2305',
#  '398',
#  '1142',
#  '1624',
#  '1630',
#  '2339',
#  '1156',
#  '429',
#  '1803',
#  '1817',
#  '2488',
#  '415',
#  '1181',
#  '373',
#  '367',
#  '1195',
#  '401',
#  '371',
#  '1183',
#  '417',
#  '403',
#  '1197',
#  '365',
#  '1829',
#  '1801',
#  '359',
#  '1815',
#  '1626',
#  '2449',
#  '1140',
#  '1154',
#  '1632',
#  '2313',
#  '2475',
#  '1168',
#  '2307',
#  '2850',
#  '2688',
#  '615',
#  '1381',
#  '173',
#  '167',
#  '1395',
#  '601',
#  '99',
#  '2844',
#  '629',
#  '2878',
#  '1342',
#  '2893',
#  '1424',
#  '1430',
#  '8',
#  '2139',
#  '2887',
#  '1356',
#  '2677',
#  '72',
#  '1418',
#  '2111',
#  '2105',
#  '198',
#  '826',
#  '66',
#  '2663',
#  '2924',
#  '761',
#  '1593',
#  '1587',
#  '775',
#  '2930',
#  '985',
#  '2918',
#  '991',
#  '749',
#  '1236',
#  '2059',
#  '1550',
#  '1544',
#  '1222',
#  '2703',
#  '946',
#  '2065',
#  '2071',
#  '1578',
#  '952',
#  '2717',
#  '2298',
#  '1791',
#  '205',
#  '563',
#  '211',
#  '1785',
#  '239',
#  '1752',
#  '1034',
#  '1020',
#  '2529',
#  '1746',
#  '2267',
#  '1008',
#  '2501',
#  '588',
#  '2273',
#  '589',
#  '2272',
#  '2266',
#  '2500',
#  '1009',
#  '2528',
#  '1021',
#  '1747',
#  '1753',
#  '1035',
#  '238',
#  '576',
#  '1784',
#  '210',
#  '204',
#  '1790',
#  '2299',
#  '562',
#  '1579',
#  '2070',
#  '2716',
#  '953',
#  '947',
#  '2702',
#  '2064',
#  '1545',
#  '1223',
#  '1237',
#  '1551',
#  '2058',
#  '748',
#  '990',
#  '2919',
#  '984',
#  '1586',
#  '2931',
#  '774',
#  '760',
#  '2925',
#  '1592',
#  '199',
#  '2104',
#  '2662',
#  '67',
#  '827',
#  '73',
#  '833',
#  '2676',
#  '2110',
#  '1419',
#  '2138',
#  '9',
#  '1431',
#  '1357',
#  '2886',
#  '2892',
#  '1343',
#  '1425',
#  '2879',
#  '628',
#  '166',
#  '2845',
#  '98',
#  '600',
#  '1394',
#  '1380',
#  '614',
#  '2689',
#  '2851',
#  '172',
#  '1169',
#  '2460',
#  '2306',
#  '2312',
#  '1155',
#  '1633',
#  '1627',
#  '1141',
#  '2448',
#  '1814',
#  '358',
#  '1800',
#  '1196',
#  '402',
#  '1828',
#  '364',
#  '370',
#  '416',
#  '1182',
#  '1867',
#  '459',
#  '1873',
#  '1683',
#  '317',
#  '471',
#  '465',
#  '303',
#  '1697',
#  '2375',
#  '2413',
#  '2407',
#  '2361',
#  '1668',
#  '2349',
#  '1898',
#  '1640',
#  '1126',
#  '1132',
#  '1654',
#  '897',
#  '129',
#  '883',
#  '673',
#  '2836',
#  '2188',
#  '115',
#  '1481',
#  '1495',
#  '101',
#  '2822',
#  '667',
#  '854',
#  '14',
#  '1318',
#  '2611',
#  '2177',
#  '2163',
#  '2605',
#  '698',
#  '868',
#  '28',
#  '1324',
#  '1442',
#  '1456',
#  '1330',
#  '2639',
#  '707',
#  '1293',
#  '2942',
#  '2956',
#  '1287',
#  '713',
#  '920',
#  '2765',
#  '2771',
#  '1278',
#  '934',
#  '2981',
#  '2759',
#  '1250',
#  '1536',
#  '1522',
#  '1244',
#  '908',
#  '1913',
#  '1907',
#  '263',
#  '2598',
#  '1091',
#  '505',
#  '511',
#  '1085',
#  '277',
#  '1708',
#  '2201',
#  '2567',
#  '2573',
#  '2215',
#  '288',
#  '1734',
#  '1052',
#  '1046',
#  '1720',
#  '2229',
#  '1047',
#  '2228',
#  '1721',
#  '1735',
#  '1053',
#  '2572',
#  '289',
#  '2214',
#  '2200',
#  '1709',
#  '2566',
#  '1084',
#  '510',
#  '276',
#  '262',
#  '504',
#  '1090',
#  '2599',
#  '1906',
#  '1912',
#  '1523',
#  '909',
#  '1245',
#  '1251',
#  '2758',
#  '2980',
#  '1537',
#  '935',
#  '1279',
#  '2770',
#  '2764',
#  '921',
#  '712',
#  '1286',
#  '2957',
#  '2943',
#  '1292',
#  '706',
#  '1457',
#  '2638',
#  '1331',
#  '1325',
#  '29',
#  '869',
#  '1443',
#  '2162',
#  '699',
#  '841',
#  '2604',
#  '2610',
#  '1319',
#  '15',
#  '855',
#  '2176',
#  '100',
#  '1494',
#  '666',
#  '2823',
#  '2837',
#  '672',
#  '1480',
#  '114',
#  '2189',
#  '882',
#  '896',
#  '128',
#  '1133',
#  '1655',
#  '1641',
#  '1899',
#  '2348',
#  '1127',
#  '2406',
#  '1669',
#  '2360',
#  '2374',
#  '2412',
#  '464',
#  '1696',
#  '302',
#  '316',
#  '1682',
#  '470',
#  '458',
#  '1872',
#  '1866',
#  '1870',
#  '328',
#  '1864',
#  '300',
#  '1694',
#  '466',
#  '472',
#  '1680',
#  '314',
#  '1858',
#  '2389',
#  '2362',
#  '499',
#  '2404',
#  '2410',
#  '1119',
#  '2376',
#  '1657',
#  '2438',
#  '1131',
#  '1125',
#  '1643',
#  '658',
#  '880',
#  '2809',
#  '894',
#  '2821',
#  '664',
#  '1496',
#  '102',
#  '116',
#  '1482',
#  '670',
#  '2835',
#  '2606',
#  '843',
#  '1469',
#  '2160',
#  '2174',
#  '857',
#  '17',
#  '2612',
#  '1333',
#  '1455',
#  '1441',
#  '2148',
#  '1327',
#  '2969',
#  '738',
#  '2955',
#  '1284',
#  '710',
#  '704',
#  '1290',
#  '2799',
#  '2941',
#  '2772',
#  '937',
#  '1509',
#  '923',
#  '2766',
#  '1247',
#  '1521',
#  '1535',
#  '2982',
#  '1253',
#  '1904',
#  '248',
#  '1910',
#  '274',
#  '512',
#  '1086',
#  '1092',
#  '506',
#  '260',
#  '2216',
#  '1079',
#  '2570',
#  '2564',
#  '2202',
#  '1723',
#  '1045',
#  '1051',
#  '2558',
#  '1737',
#  '2559',
#  '1050',
#  '1736',
#  '1722',
#  '1044',
#  '2565',
#  '2203',
#  '2217',
#  '2571',
#  '1078',
#  '507',
#  '1093',
#  '261',
#  '275',
#  '1087',
#  '513',
#  '1911',
#  '249',
#  '1905',
#  '1534',
#  '1252',
#  '2983',
#  '1246',
#  '1520',
#  '1508',
#  '2767',
#  '922',
#  '936',
#  '2773',
#  '2940',
#  '2798',
#  '1291',
#  '705',
#  '711',
#  '1285',
#  '2954',
#  '739',
#  '2968',
#  '2149',
#  '1440',
#  '1326',
#  '1332',
#  '1454',
#  '2175',
#  '2613',
#  '16',
#  '856',
#  '842',
#  '2607',
#  '2161',
#  '1468',
#  ...]

# %%
mixed_path = "/Users/Claude/Documents/GitHub/DSCI591-Fall21-RecommendationSystem/data/mixed_image_data"
for img_id in id_lst:
    filename = img_id+".png"
    if img_id not in mixed_id_lst:
        shutil.copy(os.path.join(img_path, filename), os.path.join(mixed_path, filename))

# %%
for filename in masked_lst:
    shutil.copy(os.path.join(masked_path, filename), os.path.join(mixed_path, filename))

# %%
len(os.listdir(mixed_path))
# Out:
# 2834

# %% [markdown]
# The length of the mixed_image__data looks right
